# %% [markdown]
# Task 1:
# Write a Python program to find those numbers which are divisible by 7 and
# multiple of 5, between 1500 and 2700 (both included)

# %%
for number in range(1500, 2701):
  if number % 7 == 0 and number % 5 == 0:
   print(number)
# Out:
# 1505
# 1540
# 1575
# 1610
# 1645
# 1680
# 1715
# 1750
# 1785
# 1820
# 1855
# 1890
# 1925
# 1960
# 1995
# 2030
# 2065
# 2100
# 2135
# 2170
# 2205
# 2240
# 2275
# 2310
# 2345
# 2380
# 2415
# 2450
# 2485
# 2520
# 2555
# 2590
# 2625
# 2660
# 2695

# %% [markdown]
# Task 2: Write a Python program to find numbers between 100 and 400 (both included)
# where each digit of a number is an even number. The numbers obtained should be
# printed in a comma-separated sequence.

# %%
result =[]
for number in range(100, 401):
  number = str(number)
  if (int(number[0]) %
      2 == 0 and int(number[1]) %
      2 == 0 and int(number[2]) %
      2 == 0):
    result.append(number)
    print(",".join(result))
# Out:
# 200
# 200,202
# 200,202,204
# 200,202,204,206
# 200,202,204,206,208
# 200,202,204,206,208,220
# 200,202,204,206,208,220,222
# 200,202,204,206,208,220,222,224
# 200,202,204,206,208,220,222,224,226
# 200,202,204,206,208,220,222,224,226,228
# 200,202,204,206,208,220,222,224,226,228,240
# 200,202,204,206,208,220,222,224,226,228,240,242
# 200,202,204,206,208,220,222,224,226,228,240,242,244
# 200,202,204,206,208,220,222,224,226,228,240,242,244,246
# 200,202,204,206,208,220,222,224,226,228,240,242,244,246,248
# 200,202,204,206,208,220,222,224,226,228,240,242,244,246,248,260
# 200,202,204,206,208,220,222,224,226,228,240,242,244,246,248,260,262
# 200,202,204,206,208,220,222,224,226,228,240,242,244,246,248,260,262,264
# 200,202,204,206,208,220,222,224,226,228,240,242,244,246,248,260,262,264,266
# 200,202,204,206,208,220,222,224,226,228,240,242,244,246,248,260,262,264,266,268
# 200,202,204,206,208,220,222,224,226,228,240,242,244,246,248,260,262,264,266,268,280
# ...

# %% [markdown]
# Task 3: Write a Python program to calculate the sum and average of n integer numbers

# %%
total = 0
count = 0

while True:
    num = int(input("Enter a numbr (0 to stop): "))
    if num == 0:
        break
    total += num
    count += 1
if count > 0:
    average = total / count
    print("Sum:", total)
    print("Average:", average)
else:
    print("No number were entered.")
# Out:
# Enter a numbr (0 to stop): -4
# Enter a numbr (0 to stop): 2
# Enter a numbr (0 to stop): 0
# Sum: -2
# Average: -1.0

# %% [markdown]
# Task 4:
# A student will not be allowed to sit in exam if his/her attendance is less than 75%.
# Take following input from user
#  Number of classes held
#  Number of classes attended.
#  And print percentage of class attended
#  Is student is allowed to sit in exam or not.

# %%
classes_held = int(input("Enter the number of classes held: "))
classes_attended = int(input("Enter the number of classes attended: "))
percentage = classes_attended/classes_held * 100
print("Percentage of class attended is: ", percentage)
if percentage >= 75:
    print("Student is allowed to sit in exam.")
else:
  print("Student is not allowed to sit in exam")
# Out:
# Enter the number of classes held: 27
# Enter the number of classes attended: 21
# Percentage of class attended is:  77.77777777777779
# Student is allowed to sit in exam.

# %% [markdown]
# Task 5:
# Write a Python program to perform the following tasks using lists:
#  Create a list named numbers containing integers from 1 to 5.
#  Print the original list.
#  Append the number 6 to the list.
#  Insert the number 0 at the beginning of the list.
#  Print the modified list.
#  Remove the number 3 from the list.
#  Print the final list.

# %%
numbers = [1,2,3,4,5]
print("Original list", numbers)
numbers.append(6)
numbers.insert(0,0)
print("Updated list", numbers)
numbers.remove(3)
print("Final lsit",numbers)
# Out:
# Original list [1, 2, 3, 4, 5]
# Updated list [0, 1, 2, 3, 4, 5, 6]
# Final lsit [0, 1, 2, 4, 5, 6]
